# %% [markdown]
# #IMPORTING LIBRARIES

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #LOADING OF DATASET

# %%
df=pd.read_csv("/content/Iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# #ANALIZING OF DATASET

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df["Species"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# #VISUALIZING OF DATASET

# %%
sns.histplot(data=df.head(40),x='SepalLengthCm')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Count'>

# %%
plt.figure(figsize=(12,6))
sns.distplot(df['PetalWidthCm'])
plt.xticks(xdata)
# Out:
# <ipython-input-70-43d7509be199>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['PetalWidthCm'])
# ([<matplotlib.axis.XTick at 0x7f1ce905b160>,
# ...
#  [Text(0, 0, '0'),
#   Text(1, 0, '1'),
#   Text(2, 0, '2'),
#   Text(3, 0, '3'),
#   Text(4, 0, '4'),
#   Text(5, 0, '5'),
#   Text(6, 0, '6'),
#   Text(7, 0, '7'),
#   Text(8, 0, '8'),
#   Text(9, 0, '9'),
#   Text(10, 0, '10')])

# %%
plt.figure(figsize=(12,6))
sns.jointplot(y=df['Species'],x=df['SepalWidthCm'])

# %%
plt.plot(df.Id, df["PetalLengthCm"], "b--")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.plot(kind ="scatter", x ='SepalLengthCm',y ='PetalLengthCm')
plt.grid()
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
sns.boxplot(data=df,x="Species", y="SepalLengthCm", palette="light:m_r",)
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
sns.violinplot(data=df,x="Species", y="SepalLengthCm", palette="light:m_r")
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
sns.pairplot(df.drop("Id", axis=1), hue="Species", palette="rainbow", size=3)
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.heatmap(df.corr(), annot=True)
plt.plot()
# Out:
# []

# %%
sns.lmplot(x='SepalLengthCm', y='PetalWidthCm', data=df, fit_reg=False, hue ='Species' )

# %%
plt.pie(df['PetalWidthCm'].tail(),labels=df['Species'].tail())
# Out:
# ([<matplotlib.patches.Wedge at 0x7f1ce244ba60>,
# ...
#  [Text(0.8402478291021847, 0.7099180133572229, 'Iris-virginica'),
#   Text(-0.44024724159759504, 1.008058711715597, 'Iris-virginica'),
#   Text(-1.099488374135444, -0.03354571717817534, 'Iris-virginica'),
#   Text(-0.24944362897579703, -1.071343957822783, 'Iris-virginica'),
#   Text(0.9383420764053081, -0.5740332286961923, 'Iris-virginica')])

# %%
sns.countplot(x=df['PetalWidthCm'])
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='count'>

# %%
df.plot.area()
# Out:
# <Axes: >

# %%
sns.histplot( hue="Species", palette="rainbow",x = "PetalWidthCm" , y = "SepalLengthCm",data=df)
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='SepalLengthCm'>

# %% [markdown]
# #MODEL TRAINING

# %%
from sklearn.model_selection import train_test_split
# train - 70
# test - 30
X = df.drop(columns=['Species'])
Y = df['Species']
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.30)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
print("Accuracy: ",model.score(x_test, y_test) * 100)
# Out:
# Accuracy:  100.0

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
print("Accuracy: ",model.score(x_test, y_test) * 100)
# Out:
# Accuracy:  100.0

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("Accuracy: ",model.score(x_test, y_test) * 100)
# Out:
# Accuracy:  100.0

# %%
import pickle
filename = '/content/Iris.csv'
pickle.dump(model, open(filename, 'wb'))

# %%
x_test.head()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 103  104            6.3           2.9            5.6           1.8
# 50    51            7.0           3.2            4.7           1.4
# 135  136            7.7           3.0            6.1           2.3
# 119  120            6.0           2.2            5.0           1.5
# 68    69            6.2           2.2            4.5           1.5

# %%
load_model = pickle.load(open(filename,'rb'))

# %%
load_model.predict([[6.0, 2.2, 4.0, 1.0,6.0]])
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Iris-setosa'], dtype=object)
